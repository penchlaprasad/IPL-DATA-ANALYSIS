# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv(r'D:\DATA ANALYTICS PROJECTS\IPL DATA ANALYSIS\resources\deliveries.csv')

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\Lenovo\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
#indepth analysis of DAVID warner performance
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
filt=df['batsman']=='DA Warner'

# %%
filt
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 150455    False
# 150456    False
# 150457    False
# 150458    False
# 150459    False
# Name: batsman, Length: 150460, dtype: bool

# %%
df_warner=df[filt]

# %%
df_warner.shape
# Out:
# (2902, 21)

# %%
df_warner['dismissal_kind'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='dismissal_kind'>

# %%
len(df_warner[df_warner['batsman_runs']==4])
# Out:
# 401

# %%
len(df_warner[df_warner['batsman_runs']==6])
# Out:
# 160

# %%
def count(df,runs):
    return len(df_warner[df_warner['batsman_runs']==runs])*runs

# %%
count(df_warner,1)
# Out:
# 997

# %%
count(df_warner,6)
# Out:
# 960

# %%
count(df_warner,3)
# Out:
# 39

# %%
count(df_warner,4)
# Out:
# 1604

# %%
slices=[997,414,39,1604,960]
labels=[1,2,3,4,6]
plt.pie(slices,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22d93ea30d0>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.0200956448131961, -0.4115882352948756, '4'),
#   Text(0.8038429148449225, -0.750890516822272, '6')],
#  [Text(0.4264169293674199, 0.4221002278474401, '24.8%'),
#   Text(-0.18523151829556675, 0.5706919349613407, '10.3%'),
#   Text(-0.3718342296325332, 0.4708920318646096, '1.0%'),
#   Text(-0.5564158062617433, -0.22450267379720487, '40.0%'),
#   Text(0.4384597717335941, -0.4095766455394211, '23.9%')])

# %%
slices=[997,414,39,1604,960]
labels=[1,2,3,4,6]
explode=[0,0,0,0.1,0]
plt.pie(slices,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22d93ef4eb0>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.0200956448131961, -0.4115882352948756, '4'),
#   Text(0.8038429148449225, -0.750890516822272, '6')],
#  [Text(0.4264169293674199, 0.4221002278474401, '24.8%'),
#   Text(-0.18523151829556675, 0.5706919349613407, '10.3%'),
#   Text(-0.3718342296325332, 0.4708920318646096, '1.0%'),
#   Text(-0.5564158062617433, -0.22450267379720487, '40.0%'),
#   Text(0.4384597717335941, -0.4095766455394211, '23.9%')])

# %%
slices=[997,414,39,1604,960]
labels=[1,2,3,4,6]
explode=[0,0,0,0.1,0]
plt.pie(slices,labels=labels,autopct='%1.1f%%',explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x22d93f53ac0>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.1128316125234867, -0.44900534759440974, '4'),
#   Text(0.8038429148449225, -0.750890516822272, '6')],
#  [Text(0.4264169293674199, 0.4221002278474401, '24.8%'),
#   Text(-0.18523151829556675, 0.5706919349613407, '10.3%'),
#   Text(-0.3718342296325332, 0.4708920318646096, '1.0%'),
#   Text(-0.6491517739720338, -0.261919786096739, '40.0%'),
#   Text(0.4384597717335941, -0.4095766455394211, '23.9%')])

# %%
#perform analysis on batsman performances

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
Teams={
    'Royal Challengers Bangalore':'RCB', 'Sunrisers Hyderabad':'SRH',
       'Rising Pune Supergiant':'RPS', 'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 'Gujarat Lions':'GL', 'Kings XI Punjab':'KXIP',
       'Delhi Daredevils':'DD', 'Chennai Super Kings':'CSK', 'Rajasthan Royals':'RR',
       'Deccan Chargers':'DC', 'Kochi Tuskers Kerala':'KTK', 'Pune Warriors':'PW',
       'Rising Pune Supergiants':'RPS'
}

# %%
Teams
# Out:
# {'Royal Challengers Bangalore': 'RCB',
#  'Sunrisers Hyderabad': 'SRH',
#  'Rising Pune Supergiant': 'RPS',
#  'Mumbai Indians': 'MI',
#  'Kolkata Knight Riders': 'KKR',
#  'Gujarat Lions': 'GL',
#  'Kings XI Punjab': 'KXIP',
#  'Delhi Daredevils': 'DD',
#  'Chennai Super Kings': 'CSK',
#  'Rajasthan Royals': 'RR',
#  'Deccan Chargers': 'DC',
#  'Kochi Tuskers Kerala': 'KTK',
#  'Pune Warriors': 'PW',
#  'Rising Pune Supergiants': 'RPS'}

# %%
df['batting_team']=df['batting_team'].map(Teams)

# %%
df['bowling_team']=df['bowling_team'].map(Teams)

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          NaN     1     1  DA Warner
# 1         1       1          SRH          NaN     1     2  DA Warner
# 2         1       1          SRH          NaN     1     3  DA Warner
# 3         1       1          SRH          NaN     1     4  DA Warner
# 4         1       1          SRH          NaN     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#score distribution for teams by innings

# %%
df.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
# Out:
# match_id  inning  batting_team
# 1         1       SRH             207
#           2       RCB             172
# 2         1       MI              184
#           2       RPS             187
# 3         1       GL              183
#                                  ...
# 634       2       KKR             140
# 635       1       GL              162
#           2       SRH             163
# 636       1       SRH             208
#           2       RCB             200
# Name: total_runs, Length: 1284, dtype: int64

# %%
runs=df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()

# %%
runs
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 1          2          RCB         172
# 2          1           MI         184
# 3          2          RPS         187
# 4          1           GL         183
# ...      ...          ...         ...
# 1279       2          KKR         140
# 1280       1           GL         162
# 1281       2          SRH         163
# 1282       1          SRH         208
# 1283       2          RCB         200
#
# [1284 rows x 3 columns]

# %%
runs.drop('match_id',axis=1,inplace=True)

# %%
runs
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 1          2          RCB         172
# 2          1           MI         184
# 3          2          RPS         187
# 4          1           GL         183
# ...      ...          ...         ...
# 1279       2          KKR         140
# 1280       1           GL         162
# 1281       2          SRH         163
# 1282       1          SRH         208
# 1283       2          RCB         200
#
# [1284 rows x 3 columns]

# %%
inning1=runs[runs['inning']==1]

# %%
inning1
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 2          1           MI         184
# 4          1           GL         183
# 6          1          RPS         163
# 8          1          RCB         157
# ...      ...          ...         ...
# 1274       1           DD         138
# 1276       1           GL         158
# 1278       1          SRH         162
# 1280       1           GL         162
# 1282       1          SRH         208
#
# [636 rows x 3 columns]

# %%
inning2=runs[runs['inning']==2]

# %%
inning2
# Out:
#       inning batting_team  total_runs
# 1          2          RCB         172
# 3          2          RPS         187
# 5          2          KKR         184
# 7          2         KXIP         164
# 9          2           DD         142
# ...      ...          ...         ...
# 1275       2          RCB         139
# 1277       2          RCB         159
# 1279       2          KKR         140
# 1281       2          SRH         163
# 1283       2          RCB         200
#
# [634 rows x 3 columns]

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning1)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning2)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
#how many times temas scores more than 200

# %%
high_scores=df.groupby(['match_id','inning','batting_team','bowling_team'])['total_runs'].sum()

# %%
high_scores
# Out:
# Series([], Name: total_runs, dtype: int64)

# %%
high_score=df.groupby(['match_id','inning','batting_team','bowling_team'])['total_runs'].sum().reset_index()

# %%
high_scores
# Out:
# Series([], Name: total_runs, dtype: int64)

# %%
#perform batsman copmaprision

# %%
#how many bolls played by each batsaman

# %%
balls=df.groupby('batsman')['ball'].count().reset_index()

# %%
balls
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
runs=df.groupby('batsman')['batsman_runs'].sum().reset_index()

# %%
runs
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
four=df['batsman_runs']==4

# %%
four
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 150455    False
# 150456    False
# 150457    False
# 150458    False
# 150459     True
# Name: batsman_runs, Length: 150460, dtype: bool

# %%
four=df[df['batsman_runs']==4]

# %%
four
# Out:
#         match_id  inning batting_team bowling_team  over  ball        batsman  \
# 2              1       1          SRH          NaN     1     3      DA Warner
# 8              1       1          SRH          NaN     2     2      DA Warner
# 13             1       1          SRH          NaN     2     7   MC Henriques
# 30             1       1          SRH          NaN     5     5   MC Henriques
# 32             1       1          SRH          NaN     6     1       S Dhawan
# ...          ...     ...          ...          ...   ...   ...            ...
# 150403       636       2          RCB          NaN    11     4        V Kohli
# 150407       636       2          RCB          NaN    12     2        V Kohli
# 150418       636       2          RCB          NaN    14     1       KL Rahul
# 150447       636       2          RCB          NaN    18     6    Sachin Baby
# 150459       636       2          RCB          NaN    20     6  Iqbal Abdulla
#
# ...

# %%
runs_4=four.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4.columns=['batsman','4s']
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
player=pd.concat([runs,balls.iloc[:,1],runs_4.iloc[:,1],six.iloc[:,1]],axis=1)
player
# Out:
#             batsman  batsman_runs  ball    4s    6s
# 0    A Ashish Reddy          16.0   196  16.0  16.0
# 1          A Chopra           7.0     7   7.0   7.0
# 2       A Choudhary           1.0    75   1.0   1.0
# 3        A Flintoff           5.0    20   5.0   5.0
# 4          A Kumble           3.0    57   3.0   3.0
# ..              ...           ...   ...   ...   ...
# 456             NaN           NaN   183   NaN   NaN
# 457             NaN           NaN    67   NaN   NaN
# 458             NaN           NaN     7   NaN   NaN
# 459             NaN           NaN  2050   NaN   NaN
# 460             NaN           NaN   141   NaN   NaN
#
# [461 rows x 5 columns]

# %%
#replace Nan values

# %%
player.fillna(0,inplace=True)

# %%
player
# Out:
#             batsman  batsman_runs  ball    4s    6s
# 0    A Ashish Reddy          16.0   196  16.0  16.0
# 1          A Chopra           7.0     7   7.0   7.0
# 2       A Choudhary           1.0    75   1.0   1.0
# 3        A Flintoff           5.0    20   5.0   5.0
# 4          A Kumble           3.0    57   3.0   3.0
# ..              ...           ...   ...   ...   ...
# 456               0           0.0   183   0.0   0.0
# 457               0           0.0    67   0.0   0.0
# 458               0           0.0     7   0.0   0.0
# 459               0           0.0  2050   0.0   0.0
# 460               0           0.0   141   0.0   0.0
#
# [461 rows x 5 columns]

# %%
player['strike_rate']=(player['batsman_runs']/player['ball'])*100

# %%
player
# Out:
#             batsman  batsman_runs  ball    4s    6s  strike_rate
# 0    A Ashish Reddy          16.0   196  16.0  16.0     8.163265
# 1          A Chopra           7.0     7   7.0   7.0   100.000000
# 2       A Choudhary           1.0    75   1.0   1.0     1.333333
# 3        A Flintoff           5.0    20   5.0   5.0    25.000000
# 4          A Kumble           3.0    57   3.0   3.0     5.263158
# ..              ...           ...   ...   ...   ...          ...
# 456               0           0.0   183   0.0   0.0     0.000000
# 457               0           0.0    67   0.0   0.0     0.000000
# 458               0           0.0     7   0.0   0.0     0.000000
# 459               0           0.0  2050   0.0   0.0     0.000000
# 460               0           0.0   141   0.0   0.0     0.000000
#
# [461 rows x 6 columns]

# %%
#max runs of each of the batsman

# %%
grp=df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()

# %%
grp
# Out:
#       match_id       batsman batting_team  batsman_runs
# 0            1   A Choudhary          RCB             6
# 1            1   BCJ Cutting          SRH            16
# 2            1      CH Gayle          RCB            32
# 3            1     DA Warner          SRH            14
# 4            1      DJ Hooda          SRH            16
# ...        ...           ...          ...           ...
# 9510       636     SR Watson          RCB            11
# 9511       636     STR Binny          RCB             9
# 9512       636   Sachin Baby          RCB            18
# 9513       636       V Kohli          RCB            54
# 9514       636  Yuvraj Singh          SRH            38
#
# [9515 rows x 4 columns]

# %%
grp.groupby('batsman')['batsman_runs'].max()
# Out:
# batsman
# A Ashish Reddy    36
# A Chandila         4
# A Chopra          24
# A Choudhary       15
# A Flintoff        24
#                   ..
# YV Takawale       45
# Yashpal Singh     20
# Younis Khan        3
# Yuvraj Singh      83
# Z Khan            23
# Name: batsman_runs, Length: 461, dtype: int64

# %%
max=grp.groupby('batsman')['batsman_runs'].max().reset_index()

# %%
max
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy            36
# 1        A Chandila             4
# 2          A Chopra            24
# 3       A Choudhary            15
# 4        A Flintoff            24
# ..              ...           ...
# 456     YV Takawale            45
# 457   Yashpal Singh            20
# 458     Younis Khan             3
# 459    Yuvraj Singh            83
# 460          Z Khan            23
#
# [461 rows x 2 columns]

# %%
max.columns=['batsman','max_rows']

# %%
max
# Out:
#             batsman  max_rows
# 0    A Ashish Reddy        36
# 1        A Chandila         4
# 2          A Chopra        24
# 3       A Choudhary        15
# 4        A Flintoff        24
# ..              ...       ...
# 456     YV Takawale        45
# 457   Yashpal Singh        20
# 458     Younis Khan         3
# 459    Yuvraj Singh        83
# 460          Z Khan        23
#
# [461 rows x 2 columns]

# %%
player2=pd.concat([player,max.iloc[:,1]],axis=1)

# %%
player2
# Out:
#             batsman  batsman_runs  ball    4s    6s  strike_rate  max_rows
# 0    A Ashish Reddy          16.0   196  16.0  16.0     8.163265        36
# 1          A Chopra           7.0     7   7.0   7.0   100.000000         4
# 2       A Choudhary           1.0    75   1.0   1.0     1.333333        24
# 3        A Flintoff           5.0    20   5.0   5.0    25.000000        15
# 4          A Kumble           3.0    57   3.0   3.0     5.263158        24
# ..              ...           ...   ...   ...   ...          ...       ...
# 456               0           0.0   183   0.0   0.0     0.000000        45
# 457               0           0.0    67   0.0   0.0     0.000000        20
# 458               0           0.0     7   0.0   0.0     0.000000         3
# 459               0           0.0  2050   0.0   0.0     0.000000        83
# 460               0           0.0   141   0.0   0.0     0.000000        23
#
# [461 rows x 7 columns]

# %%
#top 10 batsman

# %%
max_runs=df.groupby('batsman')['batsman_runs'].sum()

# %%
max_runs
# Out:
# batsman
# A Ashish Reddy     280
# A Chandila           4
# A Chopra            53
# A Choudhary         25
# A Flintoff          62
#                   ...
# YV Takawale        192
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2591
# Z Khan             117
# Name: batsman_runs, Length: 461, dtype: int64

# %%
max_runs=df.groupby('batsman')['batsman_runs'].sum().reset_index()

# %%
max_runs
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
max_runs=df.groupby('batsman')['batsman_runs'].sum()
max_runs.sort_values(ascending=False)[:10].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='batsman'>

# %%
#top individualscore batsman

# %%
df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index().sort_values(by='batsman_runs',ascending=False)
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9257       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# ...        ...             ...          ...           ...
# 5209       346         RE Levi           MI             0
# 5201       346        CL White           DC             0
# 7169       476       PP Chawla          KKR             0
# 540         37        AF Milne          RCB             0
# 9031       604        DJ Bravo           GL             0
#
# [9515 rows x 4 columns]

# %%
df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index().sort_values(by='batsman_runs',ascending=False).head(10)
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9257       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# 3135       206         M Vijay          CSK           127
# 529         36       DA Warner          SRH           126
# 7752       516        V Sehwag         KXIP           122
# 3686       243     PC Valthaty         KXIP           120
# 4223       279        V Sehwag           DD           119

# %%
#highest wicket taker

# %%
df['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dismissal_kinds=['caught', 'bowled', 'lbw', 'caught and bowled',
       'stumped',  'hit wicket', ]

# %%
dismissal_kinds
# Out:
# ['caught', 'bowled', 'lbw', 'caught and bowled', 'stumped', 'hit wicket']

# %%
hwt=df[df['dismissal_kind'].isin(dismissal_kinds)]

# %%
hwt
# Out:
#         match_id  inning batting_team bowling_team  over  ball  \
# 11             1       1          SRH          NaN     2     5
# 64             1       1          SRH          NaN    11     3
# 94             1       1          SRH          NaN    16     2
# 116            1       1          SRH          NaN    19     4
# 160            1       2          RCB          NaN     6     4
# ...          ...     ...          ...          ...   ...   ...
# 150402       636       2          RCB          NaN    11     3
# 150416       636       2          RCB          NaN    13     5
# 150422       636       2          RCB          NaN    14     5
# 150432       636       2          RCB          NaN    16     3
# 150438       636       2          RCB          NaN    17     3
#
#                batsman     non_striker             bowler  is_super_over  ...  \
# 11           DA Warner        S Dhawan        A Choudhary              0  ...
# ...

# %%
hwt.head()
# Out:
#      match_id  inning batting_team bowling_team  over  ball        batsman  \
# 11          1       1          SRH          NaN     2     5      DA Warner
# 64          1       1          SRH          NaN    11     3       S Dhawan
# 94          1       1          SRH          NaN    16     2   MC Henriques
# 116         1       1          SRH          NaN    19     4   Yuvraj Singh
# 160         1       2          RCB          NaN     6     4  Mandeep Singh
#
#       non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 11       S Dhawan  A Choudhary              0  ...         0            0
# 64   MC Henriques    STR Binny              0  ...         0            0
# 94   Yuvraj Singh    YS Chahal              0  ...         0            0
# 116      DJ Hooda     TS Mills              0  ...         0            0
# 160      CH Gayle  Rashid Khan              0  ...         0            0
#
# ...

# %%
hwt['bowler'].value_counts()[:10].plot()
# Out:
# <AxesSubplot:>

# %%
hwt['bowler'].value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#perform analysis on match data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'D:\DATA ANALYTICS PROJECTS\IPL DATA ANALYSIS\resources\matches.csv')

# %%
df
# Out:
#       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017       Pune   4/6/2017               Mumbai Indians
# 2      3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur  5/22/2016             Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 633  634    2016      Delhi  5/25/2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 631  False   False  False  False  False  False        False          False
# 632  False   False  False  False  False  False        False          False
# 633  False   False  False  False  False  False        False          False
# 634  False   False  False  False  False  False        False          False
# 635  False   False  False  False  False  False        False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
df.shape
# Out:
# (636, 18)

# %%
df.drop(['umpire3'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
Teams
# Out:
# {'Royal Challengers Bangalore': 'RCB',
#  'Sunrisers Hyderabad': 'SRH',
#  'Rising Pune Supergiant': 'RPS',
#  'Mumbai Indians': 'MI',
#  'Kolkata Knight Riders': 'KKR',
#  'Gujarat Lions': 'GL',
#  'Kings XI Punjab': 'KXIP',
#  'Delhi Daredevils': 'DD',
#  'Chennai Super Kings': 'CSK',
#  'Rajasthan Royals': 'RR',
#  'Deccan Chargers': 'DC',
#  'Kochi Tuskers Kerala': 'KTK',
#  'Pune Warriors': 'PW',
#  'Rising Pune Supergiants': 'RPS'}

# %%
df['team1']=df['team1'].map(Teams)
df['team2']=df['team2'].map(Teams)

# %%
df.head()
# Out:
#    id  season       city      date team1 team2                  toss_winner  \
# 0   1    2017  Hyderabad  4/5/2017   SRH   RCB  Royal Challengers Bangalore
# 1   2    2017       Pune  4/6/2017    MI   RPS       Rising Pune Supergiant
# 2   3    2017     Rajkot  4/7/2017    GL   KKR        Kolkata Knight Riders
# 3   4    2017     Indore  4/8/2017   RPS  KXIP              Kings XI Punjab
# 4   5    2017  Bangalore  4/8/2017   RCB    DD  Royal Challengers Bangalore
#
#   toss_decision  result  dl_applied                       winner  win_by_runs  \
# 0         field  normal           0          Sunrisers Hyderabad           35
# 1         field  normal           0       Rising Pune Supergiant            0
# 2         field  normal           0        Kolkata Knight Riders            0
# 3         field  normal           0              Kings XI Punjab            0
# 4           bat  normal           0  Royal Challengers Bangalore           15
#
# ...

# %%
#total matches played

# %%
df.shape[0]
# Out:
# 636

# %%
#total venues

# %%
df['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan],
#       dtype=object)

# %%
len(df['city'].unique())
# Out:
# 31

# %%
#total tems

# %%
df['team1'].unique()
# Out:
# array(['SRH', 'MI', 'GL', 'RPS', 'RCB', 'KKR', 'DD', 'KXIP', 'CSK', 'RR',
#        'DC', 'KTK', 'PW'], dtype=object)

# %%
len(df['team1'].unique())
# Out:
# 13

# %%
#most time man of the math awards

# %%
df['player_of_match'].value_counts()
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# RG Sharma         14
#                   ..
# RS Bopara          1
# PD Collingwood     1
# Z Khan             1
# JD Ryder           1
# SA Yadav           1
# Name: player_of_match, Length: 201, dtype: int64

# %%
#maximum win by runs

# %%
df['win_by_runs'].max()
# Out:
# 146

# %%
filt=df['win_by_runs'].max()
df[df['win_by_runs']==filt]
# Out:
#     id  season   city      date team1 team2       toss_winner toss_decision  \
# 43  44    2017  Delhi  5/6/2017    MI    DD  Delhi Daredevils         field
#
#     result  dl_applied          winner  win_by_runs  win_by_wickets  \
# 43  normal           0  Mumbai Indians          146               0
#
#    player_of_match             venue      umpire1    umpire2
# 43     LMP Simmons  Feroz Shah Kotla  Nitin Menon  CK Nandan

# %%
#highest wins by wickets

# %%
filt=df['win_by_wickets'].max()
df[df['win_by_wickets']==filt]
# Out:
#       id  season        city       date team1 team2  \
# 2      3    2017      Rajkot   4/7/2017    GL   KKR
# 34    35    2017  Chandigarh  4/30/2017    DD  KXIP
# 71    72    2008      Mumbai  4/27/2008    MI    DC
# 119  120    2009   Cape Town  4/19/2009  KXIP    DD
# 183  184    2010   Bangalore  3/18/2010    RR   RCB
# 298  299    2011      Mumbai  5/20/2011    MI    RR
# 376  377    2012      Jaipur  5/20/2012    RR    MI
# 390  391    2013  Chandigarh  4/10/2013  KXIP   CSK
# 542  543    2015       Delhi  4/26/2015    DD   RCB
# 590  591    2016      Rajkot  4/21/2016    GL   SRH
#
#                      toss_winner toss_decision  result  dl_applied  \
# 2          Kolkata Knight Riders         field  normal           0
# 34               Kings XI Punjab         field  normal           0
# 71               Deccan Chargers         field  normal           0
# 119             Delhi Daredevils         field  normal           1
# ...

# %%
#toss decisions each and every seasons

# %%
sns.countplot(x='season',hue='toss_decision',data=df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
#maximum toss winners

# %%
df['toss_winner'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#total matches vs wins for teams

# %%
df.head()
# Out:
#    id  season       city      date team1 team2                  toss_winner  \
# 0   1    2017  Hyderabad  4/5/2017   SRH   RCB  Royal Challengers Bangalore
# 1   2    2017       Pune  4/6/2017    MI   RPS       Rising Pune Supergiant
# 2   3    2017     Rajkot  4/7/2017    GL   KKR        Kolkata Knight Riders
# 3   4    2017     Indore  4/8/2017   RPS  KXIP              Kings XI Punjab
# 4   5    2017  Bangalore  4/8/2017   RCB    DD  Royal Challengers Bangalore
#
#   toss_decision  result  dl_applied                       winner  win_by_runs  \
# 0         field  normal           0          Sunrisers Hyderabad           35
# 1         field  normal           0       Rising Pune Supergiant            0
# 2         field  normal           0        Kolkata Knight Riders            0
# 3         field  normal           0              Kings XI Punjab            0
# 4           bat  normal           0  Royal Challengers Bangalore           15
#
# ...

# %%
df['team1'].value_counts()+df['team2'].value_counts()
# Out:
# CSK     131
# DC       75
# DD      147
# GL       30
# KKR     148
# KTK      14
# KXIP    148
# MI      157
# PW       46
# RCB     152
# RPS      30
# RR      118
# SRH      76
# dtype: int64

# %%
df['team1'].value_counts()+df['team2'].value_counts().reset_index()
# Out:
#     CSK  DC  DD  GL  KKR  KTK  KXIP  MI  PW  RCB  RPS  RR  SRH index  team2
# 0   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 1   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 2   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 3   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 4   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 5   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 6   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 7   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 8   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 9   NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# 10  NaN NaN NaN NaN  NaN  NaN   NaN NaN NaN  NaN  NaN NaN  NaN   NaN    NaN
# ...

# %%
(df['team1'].value_counts()+df['team2'].value_counts()).reset_index()
# Out:
#    index    0
# 0    CSK  131
# 1     DC   75
# 2     DD  147
# 3     GL   30
# 4    KKR  148
# 5    KTK   14
# 6   KXIP  148
# 7     MI  157
# 8     PW   46
# 9    RCB  152
# 10   RPS   30
# 11    RR  118
# 12   SRH   76

# %%
teams=(df['team1'].value_counts()+df['team2'].value_counts()).reset_index()
teams.columns=['team_name','matches_played']

# %%
teams
# Out:
#    team_name  matches_played
# 0        CSK             131
# 1         DC              75
# 2         DD             147
# 3         GL              30
# 4        KKR             148
# 5        KTK              14
# 6       KXIP             148
# 7         MI             157
# 8         PW              46
# 9        RCB             152
# 10       RPS              30
# 11        RR             118
# 12       SRH              76

# %%
df['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
df['winner'].value_counts().reset_index()
# Out:
#                           index  winner
# 0                Mumbai Indians      92
# 1           Chennai Super Kings      79
# 2         Kolkata Knight Riders      77
# 3   Royal Challengers Bangalore      73
# 4               Kings XI Punjab      70
# 5              Rajasthan Royals      63
# 6              Delhi Daredevils      62
# 7           Sunrisers Hyderabad      42
# 8               Deccan Chargers      29
# 9                 Gujarat Lions      13
# 10                Pune Warriors      12
# 11       Rising Pune Supergiant      10
# 12         Kochi Tuskers Kerala       6
# 13      Rising Pune Supergiants       5

# %%
df['winner']=df['winner'].map(Teams)

# %%
wins=df['winner'].value_counts().reset_index()

# %%
wins
# Out:
#    index  winner
# 0     MI      92
# 1    CSK      79
# 2    KKR      77
# 3    RCB      73
# 4   KXIP      70
# 5     RR      63
# 6     DD      62
# 7    SRH      42
# 8     DC      29
# 9    RPS      15
# 10    GL      13
# 11    PW      12
# 12   KTK       6

# %%
wins.columns=['team_name','wins']

# %%
wins
# Out:
#    team_name  wins
# 0         MI    92
# 1        CSK    79
# 2        KKR    77
# 3        RCB    73
# 4       KXIP    70
# 5         RR    63
# 6         DD    62
# 7        SRH    42
# 8         DC    29
# 9        RPS    15
# 10        GL    13
# 11        PW    12
# 12       KTK     6

# %%
player=teams.merge(wins,left_on='team_name',right_on='team_name',how='inner')

# %%
player
# Out:
#    team_name  matches_played  wins
# 0        CSK             131    79
# 1         DC              75    29
# 2         DD             147    62
# 3         GL              30    13
# 4        KKR             148    77
# 5        KTK              14     6
# 6       KXIP             148    70
# 7         MI             157    92
# 8         PW              46    12
# 9        RCB             152    73
# 10       RPS              30    15
# 11        RR             118    63
# 12       SRH              76    42

# %%
player['%win']=(player['wins']/player['matches_played'])*100

# %%
player
# Out:
#    team_name  matches_played  wins       %win
# 0        CSK             131    79  60.305344
# 1         DC              75    29  38.666667
# 2         DD             147    62  42.176871
# 3         GL              30    13  43.333333
# 4        KKR             148    77  52.027027
# 5        KTK              14     6  42.857143
# 6       KXIP             148    70  47.297297
# 7         MI             157    92  58.598726
# 8         PW              46    12  26.086957
# 9        RCB             152    73  48.026316
# 10       RPS              30    15  50.000000
# 11        RR             118    63  53.389831
# 12       SRH              76    42  55.263158

# %%
# !pip install plotly
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000019D0DFBD3A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/plotly/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000019D0DFBDCD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/plotly/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000019D0DFBDAF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/plotly/
# ...

# %%
#comparitive analysis of teams

# %%
#runs across the seasons

# %%
df.head()
# Out:
#    id  season       city      date team1 team2                  toss_winner  \
# 0   1    2017  Hyderabad  4/5/2017   SRH   RCB  Royal Challengers Bangalore
# 1   2    2017       Pune  4/6/2017    MI   RPS       Rising Pune Supergiant
# 2   3    2017     Rajkot  4/7/2017    GL   KKR        Kolkata Knight Riders
# 3   4    2017     Indore  4/8/2017   RPS  KXIP              Kings XI Punjab
# 4   5    2017  Bangalore  4/8/2017   RCB    DD  Royal Challengers Bangalore
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    SRH           35               0
# 1         field  normal           0    RPS            0               7
# 2         field  normal           0    KKR            0              10
# 3         field  normal           0   KXIP            0               6
# 4           bat  normal           0    RCB           15               0
#
# ...

# %%
df2=pd.read_csv(r'D:\DATA ANALYTICS PROJECTS\IPL DATA ANALYSIS\resources\deliveries.csv')

# %%
df2
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
df2.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df[['id','season']].merge(df2,left_on='id',right_on='match_id',how='left')
# Out:
#          id  season  match_id  inning                 batting_team  \
# 0         1    2017         1       1          Sunrisers Hyderabad
# 1         1    2017         1       1          Sunrisers Hyderabad
# 2         1    2017         1       1          Sunrisers Hyderabad
# 3         1    2017         1       1          Sunrisers Hyderabad
# 4         1    2017         1       1          Sunrisers Hyderabad
# ...     ...     ...       ...     ...                          ...
# 150455  636    2016       636       2  Royal Challengers Bangalore
# 150456  636    2016       636       2  Royal Challengers Bangalore
# 150457  636    2016       636       2  Royal Challengers Bangalore
# 150458  636    2016       636       2  Royal Challengers Bangalore
# 150459  636    2016       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# ...

# %%
season=df[['id','season']].merge(df2,left_on='id',right_on='match_id',how='left').drop('id',axis=1)

# %%
season
# Out:
#         season  match_id  inning                 batting_team  \
# 0         2017         1       1          Sunrisers Hyderabad
# 1         2017         1       1          Sunrisers Hyderabad
# 2         2017         1       1          Sunrisers Hyderabad
# 3         2017         1       1          Sunrisers Hyderabad
# 4         2017         1       1          Sunrisers Hyderabad
# ...        ...       ...     ...                          ...
# 150455    2016       636       2  Royal Challengers Bangalore
# 150456    2016       636       2  Royal Challengers Bangalore
# 150457    2016       636       2  Royal Challengers Bangalore
# 150458    2016       636       2  Royal Challengers Bangalore
# 150459    2016       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# ...

# %%
#runs across the seasons

# %%
season
# Out:
#         total_runs
# season
# 2008         17937
# 2009         16353
# 2010         18883
# 2011         21154
# 2012         22453
# 2013         22602
# 2014         18931
# 2015         18353
# 2016         18862
# 2017         18786

# %%
season.plot()
# Out:
# <AxesSubplot:xlabel='season'>

# %%
#average runs per match in each season

# %%
df.groupby('season')['id'].count()
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# Name: id, dtype: int64

# %%
avg_runs=df.groupby('season')['id'].count().reset_index().rename(columns={'id':'matches'})

# %%
avg_runs
# Out:
#    season  matches
# 0    2008       58
# 1    2009       57
# 2    2010       60
# 3    2011       73
# 4    2012       74
# 5    2013       76
# 6    2014       60
# 7    2015       59
# 8    2016       60
# 9    2017       59

# %%
season.reset_index(inplace=True)

# %%
season=pd.concat([avg_runs,season.iloc[:,1]],axis=1)
season
# Out:
#    season  matches  matches
# 0    2008       58       58
# 1    2009       57       57
# 2    2010       60       60
# 3    2011       73       73
# 4    2012       74       74
# 5    2013       76       76
# 6    2014       60       60
# 7    2015       59       59
# 8    2016       60       60
# 9    2017       59       59

# %%
season
# Out:
#    season  matches  matches
# 0    2008       58       58
# 1    2009       57       57
# 2    2010       60       60
# 3    2011       73       73
# 4    2012       74       74
# 5    2013       76       76
# 6    2014       60       60
# 7    2015       59       59
# 8    2016       60       60
# 9    2017       59       59

# %%
#most lucky grounds for teams

# %%
def lucky(df,team_name):
    return df[df['winner']==team_name]['venue'].value_counts().nlargest(5)

# %%
lucky(df,'MI').plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#comparision between 2 teams on the basis of their wins

# %%
def comparison(team1,team2):
    compare=df[((df['team1']==team1)|(df['team2']==team1))&((df['team1']==team2)|(df['team2']==team2))]
    sns.countplot(x='season',hue='winner',data=compare)
